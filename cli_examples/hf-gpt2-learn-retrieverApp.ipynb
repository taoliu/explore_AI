# %% [markdown]
# # Train GPT-2 for retrieverApp
#
# In this notebook, I will show how to fine-tune GPT-2 to label retrieverApp data. The goal is to correctly label the data type of a GEO entry according to the information we collect from GEO database.
#
# ## Preparation
#
# Import necessary libraries, clean GPU mem cache

# %%
import torch
from datasets import load_dataset
from peft import LoraConfig, prepare_model_for_kbit_training
from transformers import (
        AutoModelForCausalLM,
        AutoTokenizer,
        BitsAndBytesConfig,
        TrainingArguments,
        set_seed,
        pipeline
    )
from trl import SFTTrainer

torch.cuda.empty_cache()

#quantization_config = BitsAndBytesConfig(load_in_4bit=True)

# %% [markdown]
# Next, define the device, and model/tokenizer ids.

# %%
device = "cuda"

# The model that you want to train from the Hugging Face hub
model_id = "gpt2"
# Fine-tuned model name
trained_model_id = "gpt2-retrieverApp"
output_dir = 'retrieverApp_adapter/' + trained_model_id

# %% [markdown]
# Load the tokenizer.

# %%
# Load the tonenizer
tokenizer = AutoTokenizer.from_pretrained(model_id, add_eos_token=True)
tokenizer.add_special_tokens({"pad_token":"<pad>"})
tokenizer.pad_token_id = tokenizer.convert_tokens_to_ids(tokenizer.pad_token)

# Terminators
terminators = [
    tokenizer.eos_token_id,
    tokenizer.convert_tokens_to_ids("<|endoftext|>") ]

# %% [markdown]
# Configure training arguments.

# %%
# Training Arguments
training_args = TrainingArguments(
    output_dir=output_dir,
    eval_strategy="steps",
    do_eval=True,
    optim="adamw_torch",
    per_device_eval_batch_size=1, # originally set to 8
    per_device_train_batch_size=1, # originally set to 8
    gradient_accumulation_steps=4,
    log_level="info",
    save_strategy="epoch",
    learning_rate=1e-4,
    fp16= not torch.cuda.is_bf16_supported(),
    bf16= torch.cuda.is_bf16_supported(),
    eval_steps=50,
    num_train_epochs=10,
    warmup_ratio=0.1,
    lr_scheduler_type="linear",
    seed=42,
)

# LORA arguments
peft_config = LoraConfig(
    r=64, # LoRA attention dimension
    lora_alpha=16, # Alpha parameter for LoRA scaling
    lora_dropout=0.1, # Dropout probability for LoRA layers
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=["c_proj"],
)

# %% [markdown]
# Load data

# %%
set_seed(1234)  # For reproducibility

# load datasets
dataset = load_dataset("training_data")

# %% [markdown]
# Load model.

# %%
# load the model
model = AutoModelForCausalLM.from_pretrained(model_id,
                                             device_map="cuda")

# %% [markdown]
# Training.

# %%
trainer = SFTTrainer(
    model=model,
    args=training_args,
    train_dataset=dataset['train'],
    eval_dataset=dataset['validation'],
    peft_config=peft_config,
    tokenizer=tokenizer,
    max_seq_length = 1024,
)
# Out:
# /home/taoliu/miniconda3/envs/jupyterlab/lib/python3.11/site-packages/huggingface_hub/utils/_deprecation.py:100: FutureWarning: Deprecated argument(s) used in '__init__': max_seq_length. Will not be supported from version '1.0.0'.
#
# Deprecated positional argument(s) used in SFTTrainer, please use the SFTConfig to set these arguments instead.
#   warnings.warn(message, FutureWarning)
# /home/taoliu/miniconda3/envs/jupyterlab/lib/python3.11/site-packages/transformers/training_args.py:1961: FutureWarning: `--push_to_hub_token` is deprecated and will be removed in version 5 of 🤗 Transformers. Use `--hub_token` instead.
#   warnings.warn(
# /home/taoliu/miniconda3/envs/jupyterlab/lib/python3.11/site-packages/peft/tuners/lora/layer.py:1119: UserWarning: fan_in_fan_out is set to False but the target module is `Conv1D`. Setting fan_in_fan_out to True.
#   warnings.warn(
# /home/taoliu/miniconda3/envs/jupyterlab/lib/python3.11/site-packages/trl/trainer/sft_trainer.py:269: UserWarning: You passed a `max_seq_length` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# /home/taoliu/miniconda3/envs/jupyterlab/lib/python3.11/site-packages/trl/trainer/sft_trainer.py:355: UserWarning: You passed a `dataset_kwargs` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# You have loaded a model on multiple GPUs. `is_model_parallel` attribute will be force-set to `True` to avoid any unexpected behavior such as device placement mismatching.
# Using auto half precision backend

# %% [markdown]
# Train...

# %%
# To clear out cache for unsuccessful run
torch.cuda.empty_cache()

# train
trainer.train()

# save model in local
trainer.save_model()
# Out:
# ***** Running training *****
#   Num examples = 110
#   Num Epochs = 10
#   Instantaneous batch size per device = 1
#   Total train batch size (w. parallel, distributed & accumulation) = 4
#   Gradient Accumulation steps = 4
#   Total optimization steps = 270
#   Number of trainable parameters = 4,128,768
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········
# wandb: Appending key for api.wandb.ai to your netrc file: /home/taoliu/.netrc
# Tracking run with wandb version 0.17.3
# Run data is saved locally in <code>/data/taoliu/Projects/AI/explore_AI/cli_examples/wandb/run-20240628_020324-zrhoyoyr</code>
# Syncing run <strong><a href='https://wandb.ai/vladimir-liu-Roswell%20Park%20Comprehensive%20Cancer%20Center/huggingface/runs/zrhoyoyr' target="_blank">retrieverApp_adapter/gpt2-retrieverApp</a></strong> to <a href='https://wandb.ai/vladimir-liu-Roswell%20Park%20Comprehensive%20Cancer%20Center/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/vladimir-liu-Roswell%20Park%20Comprehensive%20Cancer%20Center/huggingface' target="_blank">https://wandb.ai/vladimir-liu-Roswell%20Park%20Comprehensive%20Cancer%20Center/huggingface</a>
#  View run at <a href='https://wandb.ai/vladimir-liu-Roswell%20Park%20Comprehensive%20Cancer%20Center/huggingface/runs/zrhoyoyr' target="_blank">https://wandb.ai/vladimir-liu-Roswell%20Park%20Comprehensive%20Cancer%20Center/huggingface/runs/zrhoyoyr</a>
#     <div>
#
#       <progress value='270' max='270' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [270/270 03:38, Epoch 9/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>No log</td>
#       <td>3.683316</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>No log</td>
#       <td>3.590301</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>No log</td>
#       <td>3.555403</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>No log</td>
#       <td>3.531419</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>No log</td>
#       <td>3.520983</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to retrieverApp_adapter/gpt2-retrieverApp/checkpoint-27
# loading configuration file config.json from cache at /home/taoliu/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.42.1",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in retrieverApp_adapter/gpt2-retrieverApp/checkpoint-27/tokenizer_config.json
# Special tokens file saved in retrieverApp_adapter/gpt2-retrieverApp/checkpoint-27/special_tokens_map.json
#
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 1
# Saving model checkpoint to retrieverApp_adapter/gpt2-retrieverApp/checkpoint-55
# loading configuration file config.json from cache at /home/taoliu/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.42.1",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in retrieverApp_adapter/gpt2-retrieverApp/checkpoint-55/tokenizer_config.json
# Special tokens file saved in retrieverApp_adapter/gpt2-retrieverApp/checkpoint-55/special_tokens_map.json
# Saving model checkpoint to retrieverApp_adapter/gpt2-retrieverApp/checkpoint-82
# loading configuration file config.json from cache at /home/taoliu/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.42.1",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in retrieverApp_adapter/gpt2-retrieverApp/checkpoint-82/tokenizer_config.json
# Special tokens file saved in retrieverApp_adapter/gpt2-retrieverApp/checkpoint-82/special_tokens_map.json
#
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 1
# Saving model checkpoint to retrieverApp_adapter/gpt2-retrieverApp/checkpoint-110
# loading configuration file config.json from cache at /home/taoliu/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.42.1",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in retrieverApp_adapter/gpt2-retrieverApp/checkpoint-110/tokenizer_config.json
# Special tokens file saved in retrieverApp_adapter/gpt2-retrieverApp/checkpoint-110/special_tokens_map.json
# Saving model checkpoint to retrieverApp_adapter/gpt2-retrieverApp/checkpoint-137
# loading configuration file config.json from cache at /home/taoliu/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.42.1",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in retrieverApp_adapter/gpt2-retrieverApp/checkpoint-137/tokenizer_config.json
# Special tokens file saved in retrieverApp_adapter/gpt2-retrieverApp/checkpoint-137/special_tokens_map.json
#
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 1
# Saving model checkpoint to retrieverApp_adapter/gpt2-retrieverApp/checkpoint-165
# loading configuration file config.json from cache at /home/taoliu/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.42.1",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in retrieverApp_adapter/gpt2-retrieverApp/checkpoint-165/tokenizer_config.json
# Special tokens file saved in retrieverApp_adapter/gpt2-retrieverApp/checkpoint-165/special_tokens_map.json
# Saving model checkpoint to retrieverApp_adapter/gpt2-retrieverApp/checkpoint-192
# loading configuration file config.json from cache at /home/taoliu/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.42.1",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in retrieverApp_adapter/gpt2-retrieverApp/checkpoint-192/tokenizer_config.json
# Special tokens file saved in retrieverApp_adapter/gpt2-retrieverApp/checkpoint-192/special_tokens_map.json
#
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 1
# Saving model checkpoint to retrieverApp_adapter/gpt2-retrieverApp/checkpoint-220
# loading configuration file config.json from cache at /home/taoliu/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.42.1",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in retrieverApp_adapter/gpt2-retrieverApp/checkpoint-220/tokenizer_config.json
# Special tokens file saved in retrieverApp_adapter/gpt2-retrieverApp/checkpoint-220/special_tokens_map.json
# Saving model checkpoint to retrieverApp_adapter/gpt2-retrieverApp/checkpoint-247
# loading configuration file config.json from cache at /home/taoliu/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.42.1",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in retrieverApp_adapter/gpt2-retrieverApp/checkpoint-247/tokenizer_config.json
# Special tokens file saved in retrieverApp_adapter/gpt2-retrieverApp/checkpoint-247/special_tokens_map.json
#
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 1
# Saving model checkpoint to retrieverApp_adapter/gpt2-retrieverApp/checkpoint-270
# loading configuration file config.json from cache at /home/taoliu/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.42.1",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in retrieverApp_adapter/gpt2-retrieverApp/checkpoint-270/tokenizer_config.json
# Special tokens file saved in retrieverApp_adapter/gpt2-retrieverApp/checkpoint-270/special_tokens_map.json
# Saving model checkpoint to retrieverApp_adapter/gpt2-retrieverApp/checkpoint-270
# loading configuration file config.json from cache at /home/taoliu/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.42.1",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in retrieverApp_adapter/gpt2-retrieverApp/checkpoint-270/tokenizer_config.json
# Special tokens file saved in retrieverApp_adapter/gpt2-retrieverApp/checkpoint-270/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Saving model checkpoint to retrieverApp_adapter/gpt2-retrieverApp
# loading configuration file config.json from cache at /home/taoliu/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.42.1",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in retrieverApp_adapter/gpt2-retrieverApp/tokenizer_config.json
# Special tokens file saved in retrieverApp_adapter/gpt2-retrieverApp/special_tokens_map.json
